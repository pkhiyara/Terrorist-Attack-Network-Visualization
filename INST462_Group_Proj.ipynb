# %% [markdown]
# INST462

# %%
import pandas as pd
import numpy as np

# %%
ae = pd.read_csv('AE_Nodes_Public_Version2.csv')
bali1 = pd.read_csv('Bali1_Nodes_Public_Version2.csv')
bali2 = pd.read_csv('Bali2_Nodes_Public_Version2.csv')
ce = pd.read_csv('CE_Nodes_Public_Version2.csv')
#e = pd.read_csv('Greeks_Nodes_Public_Version2.csv')
ham = pd.read_csv('Hamburg_Nodes_Public_Version2.csv')
#g = pd.read_csv('Jakarta 2009_Nodes_Public.csv')
mad = pd.read_csv('Madrid_Nodes_Public_Version2.csv')
par = pd.read_csv('PAR_Nodes_Public_Version2.csv')
sea = pd.read_csv('SEA_Nodes_Public_Version2.csv')
viv = pd.read_csv('Vivace_Nodes_Public_Version2.csv')
a1 = pd.read_csv('AE_Relations_Public_Version2.csv')
b1 = pd.read_csv('Bali1_Relations_Public_Version2.csv')
c1 = pd.read_csv('Bali2_Relations_Public_Version2.csv')
d1 = pd.read_csv('CE_Relations_Public_Version2.csv')
f1 = pd.read_csv('Hamburg_Relations_Public_Version2.csv')
h1 = pd.read_csv('Madrid_Relations_Public_Version2.csv')
i1 = pd.read_csv('PAR_Relations_Public_Version2.csv')
j1 = pd.read_csv('SEA_Relations_Public_Version2.csv')
k1 = pd.read_csv('Vivace_Relations_Public_Version2.csv')

# %%
ae["Dataset Number"] = 1
ae["Dataset"] = "Australian Embassy Bombing 2004, Indonesia"
ae["Label"] = "AE"
ae["Country"] = "Indonesia"
ae["City"] = np.nan
ae
# Out:
#       ID  Group Color Arrest_Date Release_Date Death_Date  1985_1989  \
# 0    177    NaN   red         NaN          NaN        NaN          2
# 1    577    NaN   red         NaN          NaN     9/9/04          2
# 2    598    NaN   red    1/?/2006     4/?/2008        NaN          2
# 3    800    NaN   red         NaN          NaN    4/29/06          2
# 4    801    NaN   red         NaN          NaN        NaN          2
# 5    802    NaN   red         NaN          NaN        NaN          2
# 6   1504    NaN   red     11/5/04          NaN        NaN          2
# 7   1506    NaN   red    6/?/2005          NaN        NaN          2
# 8   1507    NaN   red     9/16/04          NaN        NaN          2
# 9   1509    NaN   red    7/?/2005          NaN        NaN          2
# 10  1530    NaN   red     11/5/04          NaN        NaN          2
# 11  1534    NaN   red    9/?/2004     ?/?/2007        NaN          2
# 12  1541    NaN   red   10/?/2004    12/?/2006        NaN          2
# ...

# %%
bali1["Dataset Number"] = 2
bali1["Dataset"] = "Bali bombings 2002, Indonesia"
bali1["Label"] = "Bali 2002"
bali1["Country"] = "Indonesia"
bali1["City"] = "Bali"
bali1
# Out:
#       ID  Group Color Arrest_Date Release_Date Death_Date  1985_1989  \
# 0    151    NaN   Red   10/?/2002      6/14/06        NaN          2
# 1    153    NaN   Red    ?/?/2003          NaN        NaN          2
# 2    155    NaN   Red   12/?/2002          NaN    11/8/08          2
# 3    160    NaN   Red    11/21/02          NaN    11/8/08          2
# 4    162    NaN   Red     11/6/02          NaN    11/8/08          2
# 5    163    NaN   Red     1/13/03          NaN        NaN          2
# 6    175    NaN   Red         NaN          NaN        NaN          2
# 7    176    NaN   Red     4/22/03          NaN        NaN          2
# 8    177    NaN   Red         NaN          NaN        NaN          2
# 9    180    NaN   Red     9/27/02     3/?/2005        NaN          2
# 10   183    NaN   Red         NaN          NaN        NaN          2
# 11   189    NaN   Red         NaN          NaN        NaN          2
# 12   524    NaN   Red         NaN          NaN   10/12/02          2
# ...

# %%
bali2["Dataset Number"] = 3
bali2["Dataset"] = "Bali bombings 2005, Indonesia"
bali2["Label"] = "Bali 2005"
bali2["Country"] = "Indonesia"
bali2["City"] = "Bali"
bali2
# Out:
#       ID  Group Color Arrest_Date Release_Date Death_Date  1985_1989  \
# 0    177    NaN   Red                      NaN        NaN          2
# 1    594    NaN   Red    11/17/05      8/17/08        NaN          2
# 2    595    NaN   Red    11/18/05      1/24/10        NaN          2
# 3    596    NaN   Red    11/17/05      5/17/09        NaN          2
# 4    800    NaN   Red         NaN          NaN    4/29/06          2
# 5    810    NaN   Red    11/10/05       9/1/14        NaN          2
# 6    812    NaN   Red     1/13/06      1/13/12        NaN          2
# 7    814    NaN   Red     1/13/03          NaN    11/9/05          2
# 8    815    NaN   Red     11/1/05      11/1/20        NaN          2
# 9    816    NaN   Red     1/13/06      1/13/12        NaN          2
# 10   817    NaN   Red     1/19/06      1/19/18        NaN          2
# 11   819    NaN   Red    11/23/05     11/23/14        NaN          2
# 12   820    NaN   Red     1/18/06      1/25/06        NaN          2
# ...

# %%
ce["Dataset Number"] = 4
ce["Dataset"] = "Christmas Eve bombings 2000, Indonesia"
ce["Label"] = "CE"
ce["Country"] = "Indonesia"
ce["City"] = np.nan
ce
# Out:
#       ID  Group Color Arrest_Date Release_Date Death_Date  1985_1989  \
# 0    151    NaN   Red   10/?/2002      6/14/06        NaN          2
# 1    153    NaN   Red    ?/?/2003          NaN        NaN          2
# 2    155    NaN   Red   12/?/2002          NaN    11/8/08          2
# 3    160    NaN   Red    11/21/02          NaN    11/8/08          2
# 4    162    NaN   Red     11/6/02          NaN    11/8/08          2
# 5    163    NaN   Red     1/13/03          NaN        NaN          2
# 6    164    NaN   Red     12/9/01          NaN        NaN          2
# 7    176    NaN   Red     4/22/03          NaN        NaN          2
# 8    180    NaN   Red     9/27/02     3/?/2005        NaN          2
# 9    183    NaN   Red         NaN          NaN        NaN          2
# 10   189    NaN   Red         NaN          NaN        NaN          2
# 11   193    NaN   Red    8/?/2001          NaN        NaN          2
# 12   365    NaN   Red     4/27/03     8/?/2007        NaN          2
# ...

# %%
ham["Dataset Number"] = 5
ham["Dataset"] = "The Hamburg 9/11 Cell 2001, Germany"
ham["Label"] = "HAM 9/11"
ham["Country"] = "Germany"
ham["City"] = "Hamburg"
ham
# Out:
#       ID  Group  Color Arrest_Date Release_Date Death_Date  1985_1989  \
# 0   1012    NaN    NaN        2001          NaN        NaN          2
# 1     57    NaN    NaN         NaN          NaN        NaN          2
# 2     58    NaN    NaN        2005         2005        NaN          2
# 3   1032    NaN    NaN         NaN          NaN        NaN          2
# 4   1036    NaN    NaN         NaN          NaN        NaN          2
# 5     54    NaN    NaN   11/?/2001          NaN        NaN          2
# 6     61    NaN    NaN    10/10/02          NaN        NaN          2
# 7     60    NaN    NaN   11/?/2001          NaN        NaN          2
# 8   1014    NaN    NaN         NaN          NaN        NaN          2
# 9   1030    NaN    NaN         NaN          NaN        NaN          2
# 10    63    NaN    NaN         NaN          NaN    9/11/01          2
# 11  1037    NaN    NaN         NaN          NaN        NaN          2
# ...

# %%
mad["Dataset Number"] = 6
mad["Dataset"] = "Madrid Train Bombings 2004, Spain"
mad["Label"] = "MAD"
mad["Country"] = "Spain"
mad["City"] = np.nan
mad
# Out:
#       ID  Group Color Arrest_Date Release_Date Death_Date  1985_1989  \
# 0   3100    NaN  Blue    11/13/01          NaN        NaN          2
# 1   3101    NaN  Blue         NaN          NaN        NaN          2
# 2   3104    NaN  Blue     11/6/03          NaN        NaN          2
# 3   3106    NaN  Blue         NaN          NaN        NaN          2
# 4    318    NaN  Blue   11/?/2001          NaN        NaN          2
# 5   3132    NaN  Blue         NaN          NaN     4/3/04          2
# 6   3133    NaN  Blue     12/7/05          NaN        NaN          2
# 7   3134    NaN  Blue     3/30/04          NaN        NaN          2
# 8   3135    NaN  Blue     3/13/04          NaN        NaN          2
# 9   3136    NaN  Blue    5/?/2003          NaN        NaN          2
# 10  3137    NaN  Blue    5/?/2003          NaN        NaN          2
# 11  3138    NaN  Blue         NaN          NaN        NaN          2
# 12  3139    NaN  Blue      4/2/04          NaN        NaN          2
# ...

# %%
par["Dataset Number"] = 7
par["Dataset"] = "Philippines Ambassador Residence Bombing 2000, Jakarta"
par["Label"] = "PAR"
par["Country"] = "Indonesia"
par["City"] = "Jakarta"
par
# Out:
#       ID  Group Color Arrest_Date Release_Date Death_Date  1985_1989  \
# 0    151    NaN   Red   10/?/2002      6/14/06        NaN          2
# 1    153    NaN   Red    ?/?/2003          NaN        NaN          2
# 2    155    NaN   Red   12/?/2002          NaN    11/8/08          2
# 3    159    NaN   Red    1/?/2002          NaN   ?/?/2003          2
# 4    162    NaN   Red     11/6/02          NaN    11/8/08          2
# 5    163    NaN   Red     1/13/03          NaN        NaN          2
# 6    183    NaN   Red         NaN          NaN        NaN          2
# 7    189    NaN   Red         NaN          NaN        NaN          2
# 8    193    NaN   Red    8/?/2001          NaN        NaN          2
# 9    368    NaN   Red   12/?/2001     5/?/2006        NaN          2
# 10   587    NaN   Red         NaN          NaN        NaN          2
# 11   650    NaN   Red         NaN          NaN        NaN          2
# 12  1502    NaN   Red     1/21/03          NaN        NaN          2
# ...

# %%
sea["Dataset Number"] = 8
sea["Dataset"] = "Southeast Asian Aggregate Attack Series 2005, Indonesia"
sea["Label"] = "SEA"
sea["Country"] = "Indonesia"
sea["City"] = np.nan
sea
# Out:
#        ID  Group Color Arrest_Date Release_Date Death_Date  1985_1989  \
# 0     151    NaN   red   10/?/2002      6/14/06        NaN          2
# 1     153    NaN   red    ?/?/2003          NaN        NaN          2
# 2     155    NaN   red   12/?/2002          NaN    11/8/08          2
# 3     159    NaN   red    1/?/2002          NaN   ?/?/2003          2
# 4     160    NaN   red    11/21/02          NaN    11/8/08          2
# 5     162    NaN   red     11/6/02          NaN    11/8/08          2
# 6     163    NaN   red     1/13/03          NaN        NaN          2
# 7     164    NaN   red     12/9/01          NaN        NaN          2
# 8     175    NaN   red         NaN          NaN        NaN          2
# 9     176    NaN   red     4/22/03          NaN        NaN          2
# 10    177    NaN   red         NaN          NaN        NaN          2
# 11    180    NaN   red     9/27/02     3/?/2005        NaN          2
# ...

# %%
viv["Dataset Number"] = 9
viv["Dataset"] = "Vivace Bombing Cell 7/21/2005, London"
viv["Label"] = "VIV"
viv["Country"] = "United Kingdom"
viv["City"] = "London"
viv
# Out:
#      ID  Group   Color Arrest_Date  Release_Date  Death_Date  1985_1989  \
# 0  3000      1  Orange     7/27/05           NaN         NaN          2
# 1  3001      1  Orange    ?/?/2005           NaN         NaN          2
# 2  3002      1  Orange    ?/?/2005           NaN         NaN          2
# 3  3003      1  Orange    ?/?/2005           NaN         NaN          2
# 4  3004      1  Orange     7/29/05           NaN         NaN          2
#
#    1990_1994  Dataset Number                                Dataset Label  \
# 0          2               9  Vivace Bombing Cell 7/21/2005, London   VIV
# 1          2               9  Vivace Bombing Cell 7/21/2005, London   VIV
# 2          2               9  Vivace Bombing Cell 7/21/2005, London   VIV
# 3          2               9  Vivace Bombing Cell 7/21/2005, London   VIV
# 4          2               9  Vivace Bombing Cell 7/21/2005, London   VIV
#
#           Country    City
# 0  United Kingdom  London
# 1  United Kingdom  London
# ...

# %%
all_nodes = pd.concat([ae,bali1,bali2,ce,ham,mad,par,sea,viv],sort=False)

# %%
all_nodes.head()
# Out:
#     ID  Group Color Arrest_Date Release_Date Death_Date  1985_1989  1990_1994  \
# 0  177    NaN   red         NaN          NaN        NaN          2          2
# 1  577    NaN   red         NaN          NaN     9/9/04          2          2
# 2  598    NaN   red    1/?/2006     4/?/2008        NaN          2          2
# 3  800    NaN   red         NaN          NaN    4/29/06          2          2
# 4  801    NaN   red         NaN          NaN        NaN          2          2
#
#    Dataset Number                                     Dataset Label  \
# 0               1  Australian Embassy Bombing 2004, Indonesia    AE
# 1               1  Australian Embassy Bombing 2004, Indonesia    AE
# 2               1  Australian Embassy Bombing 2004, Indonesia    AE
# 3               1  Australian Embassy Bombing 2004, Indonesia    AE
# 4               1  Australian Embassy Bombing 2004, Indonesia    AE
#
#      Country City
# 0  Indonesia  NaN
# 1  Indonesia  NaN
# 2  Indonesia  NaN
# ...

# %%
all_nodes.to_csv('all_nodes.csv')

# %%
all_relations = pd.concat([a1,b1,c1,d1,f1,h1,i1,j1,k1],sort=False)
all_relations.head()
# Out:
#   Operation_ID  Op_role   ID  Tie_ID Tie_Year Tie_Extinguish  Kinship  \
# 0           43      NaN  177     577     2004           2004      0.0
# 1           43      NaN  177     800     2004           2006      0.0
# 2           43      NaN  177    1504     2003           2004      0.0
# 3           43      NaN  177    1507     2004           2004      0.0
# 4           43      NaN  177    1509     2004           2005      0.0
#
#   1985_1989 1990_1994
# 0       NaN       NaN
# 1       NaN       NaN
# 2       NaN       NaN
# 3       NaN       NaN
# 4       NaN       NaN

# %%
all_relations.to_csv('all_relations.csv')
